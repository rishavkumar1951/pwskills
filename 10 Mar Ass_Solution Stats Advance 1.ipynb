# %% [markdown]
# ### Q1: What is Estimation Statistics? Explain point estimate and interval estimate.
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Q2. Write a Python function to estimate the population mean using a sample mean and standard deviation.

# %%
def estimate_population_mean(sample_mean, sample_std, sample_size):
    """
    Estimate the population mean using sample statistics.

    Args:
    - sample_mean (float): The sample mean.
    - sample_std (float): The sample standard deviation.
    - sample_size (int): The sample size.

    Returns:
    - population_mean (float): The estimated population mean.
    """
    import math
    
    # Calculate the standard error (standard deviation of the sampling distribution of the mean)
    standard_error = sample_std / math.sqrt(sample_size)
    
    # Calculate the margin of error (z-score for 95% confidence level is approximately 1.96)
    margin_of_error = 1.96 * standard_error
    
    # Calculate the lower and upper bounds of the confidence interval
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error
    
    # The estimated population mean is the midpoint of the confidence interval
    population_mean = (lower_bound + upper_bound) / 2
    
    return population_mean

# Example usage:
sample_mean = 10
sample_std = 2
sample_size = 100
estimated_population_mean = estimate_population_mean(sample_mean, sample_std, sample_size)
print("Estimated Population Mean:", estimated_population_mean)
# Out:
# Estimated Population Mean: 10.0

# %% [markdown]
# This function estimates the population mean using the sample mean, sample standard deviation, and sample size. It calculates the standard error of the mean, then uses a 95% confidence interval to determine the margin of error. Finally, it calculates the estimated population mean as the midpoint of the confidence interval.

# %% [markdown]
# ### Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.
#
# Hypothesis testing is a statistical method used to make inferences about population parameters based on sample data. It involves evaluating two competing hypotheses about the population parameter of interest: the null hypothesis (\(H_0\)) and the alternative hypothesis (\(H_1\) or \(H_a\)). The goal of hypothesis testing is to assess the evidence provided by the sample data and determine whether there is enough evidence to reject the null hypothesis in favor of the alternative hypothesis.
#
# Here's a basic outline of how hypothesis testing works:
#
# 1. **Formulate Hypotheses**: The first step is to clearly state the null hypothesis (\(H_0\)), which typically represents the status quo or no effect, and the alternative hypothesis (\(H_1\) or \(H_a\)), which represents the researcher's claim or the effect of interest.
#
# 2. **Choose a Significance Level**: The significance level (\(\alpha\)) is the probability of incorrectly rejecting the null hypothesis when it is actually true. Common choices for \(\alpha\) are 0.05 (5%) and 0.01 (1%), although it can vary depending on the context.
#
# 3. **Collect Data and Calculate Test Statistic**: Data is collected from a sample, and a test statistic is calculated based on the sample data. The test statistic measures the strength of the evidence against the null hypothesis.
#
# 4. **Determine the Critical Region**: The critical region is the range of values of the test statistic that would lead to rejection of the null hypothesis at the chosen significance level.
#
# 5. **Make a Decision**: Compare the calculated test statistic to the critical region. If the test statistic falls within the critical region, the null hypothesis is rejected in favor of the alternative hypothesis. If the test statistic falls outside the critical region, the null hypothesis is not rejected.
#
# 6. **Draw Conclusions**: Based on the decision made in step 5, conclusions are drawn about the population parameter of interest. If the null hypothesis is rejected, it suggests that there is evidence in favor of the alternative hypothesis.
#
# Hypothesis testing is used for various purposes in research and decision-making, including:
#
# - **Scientific Research**: Hypothesis testing is commonly used in scientific research to test theories and hypotheses about natural phenomena.
#
# - **Quality Control**: In manufacturing and industry, hypothesis testing is used to ensure product quality and process consistency.
#
# - **Medical Research**: Hypothesis testing is used to evaluate the effectiveness of treatments and interventions in medical research.
#
# - **Business Decision-Making**: Hypothesis testing is used in business to assess marketing strategies, analyze customer behavior, and make strategic decisions.
#
# The importance of hypothesis testing lies in its ability to provide a systematic and objective approach to making decisions based on data. By rigorously evaluating hypotheses and drawing conclusions from sample data, hypothesis testing helps researchers and decision-makers make informed choices and draw reliable conclusions about the population of interest.

# %% [markdown]
# ### Q4. Create a hypothesis that states whether the average weight of male college students is greater than the average weight of female college students.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Q5. Write a Python script to conduct a hypothesis test on the difference between two population means, given a sample from each population.

# %%
import numpy as np
from scipy import stats

def two_sample_t_test(sample1, sample2, alpha=0.05, alternative='two-sided'):
    """
    Perform a two-sample t-test to compare the means of two populations.

    Args:
    - sample1 (array-like): Sample data from population 1.
    - sample2 (array-like): Sample data from population 2.
    - alpha (float): Significance level for the test.
    - alternative (str): The alternative hypothesis ('two-sided', 'greater', or 'less').

    Returns:
    - t_statistic (float): The calculated t-statistic.
    - p_value (float): The p-value associated with the test.
    - reject_null (bool): True if null hypothesis is rejected, False otherwise.
    """
    t_statistic, p_value = stats.ttest_ind(sample1, sample2)

    if alternative == 'two-sided':
        reject_null = p_value < alpha
    elif alternative == 'greater':
        reject_null = (t_statistic > 0) and (p_value < alpha)
    elif alternative == 'less':
        reject_null = (t_statistic < 0) and (p_value < alpha)
    else:
        raise ValueError("Invalid alternative hypothesis. Choose 'two-sided', 'greater', or 'less'.")

    return t_statistic, p_value, reject_null

# Example usage:
# Generate sample data for two populations
np.random.seed(123)
sample1 = np.random.normal(loc=50, scale=10, size=30)  # Sample data from population 1
sample2 = np.random.normal(loc=55, scale=12, size=35)  # Sample data from population 2

# Perform two-sample t-test
t_stat, p_val, reject_null = two_sample_t_test(sample1, sample2)

# Print results
print("Results of Two-Sample t-test:")
print("t-statistic:", t_stat)
print("p-value:", p_val)
print("Null Hypothesis Rejected:", reject_null)
# print(sample1)
# print(sample2)
# Out:
# Results of Two-Sample t-test:
# t-statistic: -1.8583409120914411
# p-value: 0.06779388516431879
# Null Hypothesis Rejected: False

# %% [markdown]
# ### Q6: What is a null and alternative hypothesis? Give some examples.
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Q7: Write down the steps involved in hypothesis testing.
#
#
# Here are the general steps involved in hypothesis testing:
#
# 1. **Formulate Hypotheses**:
#    - Define the null hypothesis (\(H_0\)) and the alternative hypothesis (\(H_1\) or \(H_a\)).
#    - \(H_0\) typically represents the status quo or no effect, while \(H_1\) represents the researcher's claim or the effect of interest.
#
# 2. **Choose a Significance Level (\(\alpha\))**:
#    - Select a significance level (\(\alpha\)), which is the probability of incorrectly rejecting the null hypothesis when it is actually true.
#    - Common choices for \(\alpha\) include 0.05 (5%) and 0.01 (1%), but it can vary depending on the context and the desired level of confidence.
#
# 3. **Select a Test Statistic**:
#    - Choose an appropriate test statistic that will be used to assess the evidence provided by the sample data in relation to the null hypothesis.
#    - The choice of test statistic depends on factors such as the type of data being analyzed and the specific hypothesis being tested.
#
# 4. **Collect Data and Calculate Test Statistic**:
#    - Collect data from a sample or samples that are representative of the population(s) of interest.
#    - Calculate the value of the chosen test statistic based on the sample data.
#
# 5. **Determine the Critical Region**:
#    - Define the critical region, which is the range of values of the test statistic that would lead to rejection of the null hypothesis at the chosen significance level (\(\alpha\)).
#    - The critical region is determined based on the distribution of the test statistic under the null hypothesis.
#
# 6. **Calculate the P-value**:
#    - Calculate the p-value, which is the probability of observing a test statistic as extreme or more extreme than the one calculated from the sample data, assuming that the null hypothesis is true.
#
# 7. **Make a Decision**:
#    - Compare the calculated test statistic or p-value to the critical region or the significance level.
#    - If the test statistic falls within the critical region or the p-value is less than \(\alpha\), reject the null hypothesis in favor of the alternative hypothesis.
#    - If the test statistic does not fall within the critical region or the p-value is greater than or equal to \(\alpha\), fail to reject the null hypothesis.
#
# 8. **Draw Conclusions**:
#    - Based on the decision made in step 7, draw conclusions about the population parameter(s) of interest.
#    - If the null hypothesis is rejected, it suggests that there is evidence in favor of the alternative hypothesis.
#    - If the null hypothesis is not rejected, it suggests that there is not enough evidence to support the alternative hypothesis.
#
# These steps provide a systematic and structured approach to hypothesis testing, allowing researchers to evaluate hypotheses and draw meaningful conclusions based on sample data.

# %% [markdown]
# ### Q8. Define p-value and explain its significance in hypothesis testing.
#
#
# The p-value, or probability value, is a measure that quantifies the strength of evidence against the null hypothesis in hypothesis testing. It represents the probability of observing a test statistic as extreme or more extreme than the one calculated from the sample data, assuming that the null hypothesis is true.
#
# Here's a more detailed explanation of the significance of the p-value in hypothesis testing:
#
# 1. **Interpretation**:
#    - A low p-value indicates strong evidence against the null hypothesis, suggesting that it is unlikely that the observed results occurred by chance alone.
#    - A high p-value, on the other hand, suggests weak evidence against the null hypothesis, indicating that the observed results could plausibly occur even if the null hypothesis is true.
#
# 2. **Decision Rule**:
#    - In hypothesis testing, the p-value is compared to the significance level (\(\alpha\)) chosen for the test.
#    - If the p-value is less than or equal to the significance level (\(p \leq \alpha\)), the null hypothesis is rejected in favor of the alternative hypothesis.
#    - If the p-value is greater than the significance level (\(p > \alpha\)), the null hypothesis is not rejected.
#
# 3. **Level of Confidence**:
#    - The p-value provides a measure of the level of confidence in the decision made during hypothesis testing.
#    - A smaller p-value indicates higher confidence in rejecting the null hypothesis.
#    - The significance level (\(\alpha\)) chosen for the test determines the threshold for considering a p-value small enough to reject the null hypothesis.
#
# 4. **Interpretation Across Studies**:
#    - The p-value allows researchers to compare the strength of evidence against the null hypothesis across different studies and analyses.
#    - A smaller p-value suggests more convincing evidence against the null hypothesis, regardless of the specific context or sample size.
#
# 5. **Robustness**:
#    - The p-value is a robust measure that accounts for variations in sample size, study design, and other factors.
#    - It provides a standardized metric for assessing the significance of results across different analyses and studies.
#
# In summary, the p-value plays a crucial role in hypothesis testing by quantifying the strength of evidence against the null hypothesis. It helps researchers make informed decisions about whether to reject or fail to reject the null hypothesis based on the observed sample data.

# %% [markdown]
# ### Q9. Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom parameter set to 10.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

# Define the range of x values
x = np.linspace(-5, 5, 1000)

# Degrees of freedom
df = 10

# Calculate the probability density function (PDF) of the t-distribution
pdf = t.pdf(x, df)

# Plot the t-distribution
plt.figure(figsize=(8, 6))
plt.plot(x, pdf, label=f"Degrees of Freedom = {df}")
plt.title("Student's t-Distribution")
plt.xlabel("x")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# In this code:
#
# - We import the necessary libraries: numpy for numerical computations, matplotlib.pyplot for plotting, and scipy.stats.t for the Student's t-distribution.
# - We define the range of x values using numpy's linspace function to span from -5 to 5 with 1000 points.
# - We set the degrees of freedom (df) parameter to 10.
# - We calculate the probability density function (PDF) of the t-distribution using the t.pdf function from scipy.stats.
# - Finally, we plot the t-distribution using matplotlib.pyplot.plot, with the x values on the x-axis and the PDF values on the y-axis. We also add a title, labels, legend, and grid to the plot for better visualization.

# %% [markdown]
# ### Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two random samples of equal size and a null hypothesis that the population means are equal.

# %%
import numpy as np
from scipy import stats

def two_sample_t_test(sample1, sample2, alpha=0.05):
    """
    Perform a two-sample t-test for independent samples.

    Args:
    - sample1 (array-like): Sample data from population 1.
    - sample2 (array-like): Sample data from population 2.
    - alpha (float): Significance level for the test (default is 0.05).

    Returns:
    - t_statistic (float): The calculated t-statistic.
    - p_value (float): The p-value associated with the test.
    - reject_null (bool): True if null hypothesis is rejected, False otherwise.
    """
    t_statistic, p_value = stats.ttest_ind(sample1, sample2)

    reject_null = p_value < alpha

    return t_statistic, p_value, reject_null

# Generate random samples of equal size from two populations
np.random.seed(123)
sample_size = 30
sample1 = np.random.normal(loc=50, scale=10, size=sample_size)  # Sample data from population 1
sample2 = np.random.normal(loc=55, scale=12, size=sample_size)  # Sample data from population 2

# Perform two-sample t-test
t_stat, p_val, reject_null = two_sample_t_test(sample1, sample2)

# Print results
print("Results of Two-Sample t-test:")
print("t-statistic:", t_stat)
print("p-value:", p_val)
print("Null Hypothesis Rejected:", reject_null)
# Out:
# Results of Two-Sample t-test:
# t-statistic: -1.8050620104670085
# p-value: 0.07625647997730674
# Null Hypothesis Rejected: False

# %% [markdown]
# ### Q11: What is Student’s t distribution? When to use the t-Distribution.
#
# https://www.investopedia.com/terms/t/tdistribution.asp#:~:text=our%20editorial%20policies-,What%20Is%20a%20T%2DDistribution%3F,sample%20sizes%20or%20unknown%20variances.
#
# https://www.geeksforgeeks.org/students-t-distribution-in-statistics/
#
#
# The Student's t-distribution, often referred to simply as the t-distribution, is a probability distribution that is similar in shape to the standard normal distribution but has heavier tails. It is used in hypothesis testing and confidence interval estimation when the sample size is small or when the population standard deviation is unknown.
#
# Here are some key points about the t-distribution and when to use it:
#
# 1. **Shape**:
#    - The t-distribution is symmetric and bell-shaped, like the standard normal distribution, but it has thicker tails. As the degrees of freedom increase, the t-distribution approaches the standard normal distribution.
#
# 2. **Parameter**:
#    - The t-distribution is characterized by a single parameter called the degrees of freedom (\(df\)). The degrees of freedom represent the number of independent observations used to estimate a statistic. As the degrees of freedom increase, the t-distribution becomes closer to the standard normal distribution.
#
# 3. **Use Cases**:
#    - The t-distribution is commonly used in situations where the sample size is small (typically less than 30) or when the population standard deviation is unknown.
#    - It is used in hypothesis testing to compare sample means or proportions, particularly when the sample size is small and/or the population standard deviation is unknown.
#    - The t-distribution is also used to construct confidence intervals for population parameters, such as the mean or difference in means.
#
# 4. **Hypothesis Testing**:
#    - When performing hypothesis tests on sample means with small sample sizes or unknown population standard deviations, the t-distribution is used to calculate critical values and p-values.
#    - The t-test is used to determine whether there is a significant difference between the means of two samples or between a sample mean and a population mean.
#
# 5. **Confidence Intervals**:
#    - When constructing confidence intervals for population parameters (e.g., population mean), the t-distribution is used instead of the standard normal distribution when the sample size is small or the population standard deviation is unknown.
#    - The width of the confidence interval depends on the confidence level chosen and the sample size, with wider intervals for lower confidence levels and smaller sample sizes.
#
# In summary, the t-distribution is used in statistical inference when dealing with small sample sizes or unknown population standard deviations. It provides critical values, p-values, and confidence intervals that are appropriate for these scenarios, making it a valuable tool in hypothesis testing and estimation.

# %% [markdown]
# ### Q12: What is t-statistic? State the formula for t-statistic.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random sample of 50 days and find the sample mean revenue to be $500 with a standard deviation of $50. Estimate the population mean revenue with a 95% confidence interval.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np
from scipy.stats import t

# Given data
sample_mean = 500
sample_std = 50
sample_size = 50
confidence_level = 0.95

# Calculate the critical value from the t-distribution
degrees_of_freedom = sample_size - 1
t_critical = t.ppf((1 + confidence_level) / 2, df=degrees_of_freedom)

# Calculate the margin of error
margin_of_error = t_critical * (sample_std / np.sqrt(sample_size))

# Calculate the confidence interval
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

# Print the confidence interval
print("95% Confidence Interval for Population Mean Revenue:")
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
# Out:
# 95% Confidence Interval for Population Mean Revenue:
# Lower Bound: 485.79015724388137
# Upper Bound: 514.2098427561186

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q14. A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np
from scipy.stats import t

# Given data
sample_mean = 8
population_mean_null = 10
sample_std = 3
sample_size = 100
significance_level = 0.05

# Calculate the t-statistic
t_statistic = (sample_mean - population_mean_null) / (sample_std / np.sqrt(sample_size))

# Calculate the critical value from the t-distribution
degrees_of_freedom = sample_size - 1
t_critical = t.ppf(significance_level, df=degrees_of_freedom)

# Print the results
print("t-statistic:", t_statistic)
print("Critical value from t-distribution:", t_critical)

# Compare the t-statistic with the critical value
if t_statistic < t_critical:
    print("Null hypothesis rejected. There is sufficient evidence to conclude that the new drug decreases blood pressure.")
else:
    print("Null hypothesis not rejected. There is not sufficient evidence to conclude that the new drug decreases blood pressure.")
# Out:
# t-statistic: -6.666666666666667
# Critical value from t-distribution: -1.6603911559963902
# Null hypothesis rejected. There is sufficient evidence to conclude that the new drug decreases blood pressure.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q15. An electronics company produces a certain type of product with a mean weight of 5 pounds and a standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5 pounds with a significance level of 0.01.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np
from scipy.stats import t

# Given data
sample_mean = 4.8
population_mean = 5
population_std = 0.5
sample_size = 25
significance_level = 0.01

# Calculate the t-statistic
t_statistic = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# Calculate the critical value from the t-distribution
degrees_of_freedom = sample_size - 1
t_critical = t.ppf(significance_level, df=degrees_of_freedom)

# Print the results
print("t-statistic:", t_statistic)
print("Critical value from t-distribution:", t_critical)

# Compare the t-statistic with the critical value
if t_statistic < t_critical:
    print("Null hypothesis rejected. There is sufficient evidence to conclude that the true mean weight of the products is less than 5 pounds.")
else:
    print("Null hypothesis not rejected. There is not sufficient evidence to conclude that the true mean weight of the products is less than 5 pounds.")
# Out:
# t-statistic: -2.0000000000000018
# Critical value from t-distribution: -2.4921594731575762
# Null hypothesis not rejected. There is not sufficient evidence to conclude that the true mean weight of the products is less than 5 pounds.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q16. Two groups of students are given different study materials to prepare for a test. The first group (n1 = 30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two groups are equal with a significance level of 0.01.
#
# ![image.png](attachment:image.png)

# %%
import numpy as np
from scipy.stats import t

# Given data for group 1
sample_mean1 = 80
sample_std1 = 10
sample_size1 = 30

# Given data for group 2
sample_mean2 = 75
sample_std2 = 8
sample_size2 = 40

# Significance level
significance_level = 0.01

# Calculate the pooled standard deviation
pooled_std = np.sqrt(((sample_size1 - 1) * sample_std1**2 + (sample_size2 - 1) * sample_std2**2) / (sample_size1 + sample_size2 - 2))

# Calculate the t-statistic
t_statistic = (sample_mean1 - sample_mean2) / np.sqrt((sample_std1**2 / sample_size1) + (sample_std2**2 / sample_size2))

# Calculate the degrees of freedom
degrees_of_freedom = sample_size1 + sample_size2 - 2

# Calculate the critical value from the t-distribution
t_critical = t.ppf(1 - significance_level / 2, df=degrees_of_freedom)

# Print the results
print("t-statistic:", t_statistic)
print("Critical value from t-distribution:", t_critical)

# Compare the t-statistic with the critical value
if abs(t_statistic) > t_critical:
    print("Null hypothesis rejected. There is sufficient evidence to conclude that the population means for the two groups are not equal.")
else:
    print("Null hypothesis not rejected. There is not sufficient evidence to conclude that the population means for the two groups are not equal.")
# Out:
# t-statistic: 2.2511258444537408
# Critical value from t-distribution: 2.6500812928169553
# Null hypothesis not rejected. There is not sufficient evidence to conclude that the population means for the two groups are not equal.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard deviation of 1.5. Estimate the population mean with a 99% confidence interval.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np
from scipy.stats import t

# Given data
sample_mean = 4
sample_std = 1.5
sample_size = 50
confidence_level = 0.99

# Calculate the critical value from the t-distribution
degrees_of_freedom = sample_size - 1
t_critical = t.ppf((1 + confidence_level) / 2, df=degrees_of_freedom)

# Calculate the margin of error
margin_of_error = t_critical * (sample_std / np.sqrt(sample_size))

# Calculate the confidence interval
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

# Print the confidence interval
print("99% Confidence Interval for Population Mean Number of Ads Watched:")
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
# Out:
# 99% Confidence Interval for Population Mean Number of Ads Watched:
# Lower Bound: 3.4314963358572577
# Upper Bound: 4.568503664142742

# %% [markdown]
# ![image.png](attachment:image.png)
